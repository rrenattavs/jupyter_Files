# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Markdown, clear_output
import ipywidgets as widgets

x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

fig, ax = plt.subplots(1, 1)
ax.scatter(x, y)

ax.grid(b=True, which='major')
ax.grid(b=True, which='minor')


menu = widgets.Dropdown(
       options=['red', 'blue', 'green'],
       value='red',
       description='Color:')
menu

display(menu)
# Out:
# Dropdown(description='Color:', options=('red', 'blue', 'green'), value='red')

# %%
menu.value
# Out:
# 'red'

# %%
output = widgets.Output()
 
# create some x data
x = np.linspace(0, 2 * np.pi, 100)
 
# default line color
initial_color = menu.value
 
with output:
    fig, ax = plt.subplots(constrained_layout=True, figsize=(6, 4))

fig.canvas.toolbar_position = 'bottom'
ax.grid(True)    
line, = ax.plot(x, np.sin(x), initial_color)

# %%
df_tips = sns.load_dataset("tips")

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
menusex = widgets.Dropdown(
       options=['female', 'male'],
       value='male',
       description='sex:')
display(menusex)
# Out:
# Dropdown(description='sex:', index=1, options=('female', 'male'), value='male')

# %%
sns.relplot(x='total_bill', y= 'tip', hue='sex', data=df_tips)
